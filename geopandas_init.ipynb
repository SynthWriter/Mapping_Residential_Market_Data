# %%
import warnings
warnings.filterwarnings('ignore')

import ipyleaflet
from ipyleaflet import Map, GeoData, basemaps, WidgetControl, GeoJSON,  \
                       LayersControl, Icon, Marker, basemap_to_tiles,    \
                       Choropleth, MarkerCluster, Heatmap, SearchControl, \
                       FullScreenControl

import IPython.display
from IPython.display import Image, display, display_html

import ipywidgets as ipw
from ipywidgets import Text, HTML, link, FloatSlider

import branca as br
from branca.colormap import linear

import geopandas as gpd
from geopandas import read_file

import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import folium as fol
import mapclassify as mc
import pandas as pd
import numpy as np
import os
import requests

# Keeping plots embedded within our Jupyter Notebook
# %matplotlib inline

# Importing dark theme for data visualizations
__import__ ('jupyterthemes').jtplot.style()

# %%
# Sample test run (test mapping Asia)
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

center = [30.546647, 79.373178]
zoom = 3

asia = countries[countries['continent'] == 'Asia']
asia_map = \
Map(
    basemap=basemaps.CartoDB.Positron,
    center=center,
    zoom=zoom
)
geodata = \
GeoData(
    geo_dataframe = asia, 
    style={
        'color': 'black',
        'fillColor': '#E0D071',
        'opacity':0.03,
        'weight':1.9,
        'dashArray':'2',
        'fillOpacity':0.6
    },
    hover_style={'fillColor': '#b08a3e' , 'fillOpacity': 0.8},
    name = 'Countries'
)
asia_map.add_layer(geodata)
asia_map
# Out:
# Map(center=[30.546647, 79.373178], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
# Listing all territories within North America
countries.loc[countries['continent'] == 'North America']
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# 16    11263077.0  North America                     Haiti    HTI       14332
# 17    10738958.0  North America            Dominican Rep.    DOM       88941
# 19      389482.0  North America                   Bahamas    BHS       13578
# 22       56225.0  North America                 Greenland    GRL        3051
# 27   127575529.0  North America                    Mexico    MEX     1268870
# 33     4246439.0  North America                    Panama    PAN       66800
# 34     5047561.0  North America                Costa Rica    CRI       61801
# 35     6545502.0  North America                 Nicaragua    NIC       12520
# 36     9746117.0  North America                  Honduras    HND       25095
# 37     6453553.0  North America               El Salvador    SLV       27022
# 38    16604026.0  North America                 Guatemala    GTM       76710
# 39      390353.0  North America                    Belize    BLZ        1879
# 45     3193694.0  North America               Puerto Rico    PRI      104988
# 46     2948279.0  North America                   Jamaica    JAM       16458
# 47    11333483.0  North America                      Cuba    CUB      100023
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
#
#                                               geometry
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# 16   POLYGON ((-71.71236 19.71446, -71.62487 19.169...
# 17   POLYGON ((-71.70830 18.04500, -71.68774 18.316...
# 19   MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...
# 22   POLYGON ((-46.76379 82.62796, -43.40644 83.225...
# 27   POLYGON ((-117.12776 32.53534, -115.99135 32.6...
# 33   POLYGON ((-77.35336 8.67050, -77.47472 8.52429...
# 34   POLYGON ((-82.54620 9.56613, -82.93289 9.47681...
# 35   POLYGON ((-83.65561 10.93876, -83.89505 10.726...
# 36   POLYGON ((-83.14722 14.99583, -83.48999 15.016...
# 37   POLYGON ((-89.35333 14.42413, -89.05851 14.340...
# 38   POLYGON ((-92.22775 14.53883, -92.20323 14.830...
# 39   POLYGON ((-89.14308 17.80832, -89.15091 17.955...
# 45   POLYGON ((-66.28243 18.51476, -65.77130 18.426...
# 46   POLYGON ((-77.56960 18.49053, -76.89662 18.400...
# 47   POLYGON ((-82.26815 23.18861, -81.40446 23.117...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...

# %%
# Viewing default data for gpd's naturalearth_lowres set
test_usa = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
test_usa.sample(5)
# Out:
#         pop_est continent                  name iso_a3  gdp_md_est  \
# 164   6777452.0    Africa                 Libya    LBY       52091
# 148  31949777.0      Asia              Malaysia    MYS      364681
# 109   2957731.0      Asia               Armenia    ARM       13672
# 84    9770529.0      Asia  United Arab Emirates    ARE      421142
# 26    2125268.0    Africa               Lesotho    LSO        2376
#
#                                               geometry
# 164  POLYGON ((25.00000 22.00000, 25.00000 20.00304...
# 148  MULTIPOLYGON (((100.08576 6.46449, 100.25960 6...
# 109  POLYGON ((46.50572 38.77061, 46.14362 38.74120...
# 84   POLYGON ((51.57952 24.24550, 51.75744 24.29407...
# 26   POLYGON ((28.97826 -28.95560, 29.32517 -29.257...

# %%
cds = gpd.read_file('C:/Users/remar/OneDrive/Desktop/Code/SynthWriter/Current Market Rental Data Analysis/geo_shape_files/congressional_districts/cb_2020_us_cd116_20m.shp')
type(cds)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
display(
    cds.info(),
    cds.sample(10)
)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATEFP   437 non-null    object
#  1   CD116FP   437 non-null    object
#  2   AFFGEOID  437 non-null    object
#  3   GEOID     437 non-null    object
#  4   NAMELSAD  437 non-null    object
#  5   LSAD      437 non-null    object
#  6   CDSESSN   437 non-null    object
#  7   ALAND     437 non-null    int64
#  8   AWATER    437 non-null    int64
#  9   geometry  437 non-null    geometry
# dtypes: geometry(1), int64(2), object(7)
# memory usage: 34.3+ KB
# None
#     STATEFP CD116FP       AFFGEOID GEOID                   NAMELSAD LSAD  \
# 3        36      01  5001600US3601  3601   Congressional District 1   C2
# 328      12      02  5001600US1202  1202   Congressional District 2   C2
# 141      51      04  5001600US5104  5104   Congressional District 4   C2
# 111      25      08  5001600US2508  2508   Congressional District 8   C2
# 6        48      35  5001600US4835  4835  Congressional District 35   C2
# 258      05      03  5001600US0503  0503   Congressional District 3   C2
# 296      39      16  5001600US3916  3916  Congressional District 16   C2
# 105      36      07  5001600US3607  3607   Congressional District 7   C2
# 365      17      18  5001600US1718  1718  Congressional District 18   C2
# 67       26      11  5001600US2611  2611  Congressional District 11   C2
#
#     CDSESSN        ALAND      AWATER  \
# 3       116   1684046571  3359943463
# 328     116  28500816318  9297236174
# 141     116   9433217400   296493194
# 111     116    844339683   448445056
# 6       116   1540484180    18890415
# 258     116  13985796400   374570670
# 296     116   3121705125    31215207
# 105     116     41802690     2679594
# 365     116  27234848169   383625124
# 67      116   1085486513    55928940
#
#                                               geometry
# 3    MULTIPOLYGON (((-72.01893 41.27411, -71.92680 ...
# 328  POLYGON ((-85.99274 30.38932, -85.85977 30.490...
# 141  POLYGON ((-77.90025 37.14388, -77.79593 37.192...
# 111  POLYGON ((-71.22917 42.26415, -71.18821 42.280...
# 6    POLYGON ((-98.52602 29.46636, -98.49180 29.456...
# 258  POLYGON ((-94.61792 36.49941, -94.36120 36.499...
# 296  POLYGON ((-82.12933 40.99181, -81.97738 40.989...
# 105  POLYGON ((-74.03093 40.72279, -74.02349 40.737...
# 365  POLYGON ((-91.50626 40.20016, -91.49696 40.248...
# 67   POLYGON ((-83.68278 42.69558, -83.21403 42.709...

# %%
# Testing additional congressional districts dataset
center = [37.546647, -90.373178]
zoom = 4

congress_districs = cds[cds['STATEFP'] == '12']
usa_map = \
Map(
    basemap=basemaps.CartoDB.Positron,
    center=center,
    zoom=zoom
)
geodata = \
GeoData(
    geo_dataframe = cds, 
    style={
        'color': 'black',
        'fillColor': '#E0D071',
        'opacity':0.03,
        'weight':1.9,
        'dashArray':'2',
        'fillOpacity':0.6
    },
    hover_style={'fillColor': '#b08a3e' , 'fillOpacity': 0.8},
    name = 'Countries'
)
usa_map.add_layer(geodata)
usa_map
# Out:
# Map(center=[37.546647, -90.373178], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %%
# Reading data on counties (with geodataframe polygons) and zip codes (from raw csv file)
df_counties = gpd.read_file('https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_county_20m.zip')

geo_data_url = 'https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv'

# Examining datatypes
print(
    ' df_counties datatype = {} \
    \n geo_data_url datatype = {}'
    .format(
        type(df_counties),
        type(geo_data_url)
    )
)
# Out:
#  df_counties datatype = <class 'geopandas.geodataframe.GeoDataFrame'>
#  geo_data_url datatype = <class 'str'>

# %%
#### OPTIMIZED NEW DF WITH OPPORTUNITY FOR STATE_CODE ENTRY

#df_all_ga_counties = df_counties.loc[df_counties['STUSPS'] == ''+state_code+'']
df_all_ga_counties = df_counties.loc[df_counties['STUSPS'] == 'GA']
df_all_ga_counties
df_counties.sample(5)
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME  \
# 1789      39      167  01074095  0500000US39167  39167  Washington
# 1297      29      151  00758530  0500000US29151  29151       Osage
# 847       51      775  01789074  0500000US51775  51775       Salem
# 397       21      079  00516886  0500000US21079  21079     Garrard
# 2970      13      173  00348102  0500000US13173  13173      Lanier
#
#                NAMELSAD STUSPS STATE_NAME LSAD       ALAND    AWATER  \
# 1789  Washington County     OH       Ohio   06  1636805226  20784952
# 1297       Osage County     MO   Missouri   06  1571034361  17734586
# 847          Salem city     VA   Virginia   25    37593968    275156
# 397      Garrard County     KY   Kentucky   06   595979380   9931261
# 2970      Lanier County     GA    Georgia   06   509030778   8418857
#
#                                                geometry
# 1789  POLYGON ((-81.84486 39.45022, -81.82316 39.494...
# 1297  POLYGON ((-92.19448 38.33554, -92.11498 38.401...
# 847   POLYGON ((-80.12049 37.28705, -80.02223 37.308...
# 397   POLYGON ((-84.68934 37.72727, -84.71693 37.815...
# 2970  POLYGON ((-83.19797 31.02540, -83.16507 31.147...

# %%
# Converting str datatype to pandas dataframe
df_geo = pd.read_csv(geo_data_url)
print(' df_geo datatype = {}'.format(type(df_geo)))
# Out:
#  df_geo datatype = <class 'pandas.core.frame.DataFrame'>

# %%
display(
    df_counties.loc[df_counties['NAME'] == 'Shelby'].nunique(),
    df_geo.loc[df_geo['county'] == 'Shelby'].nunique()
)
# Out:
# STATEFP       9
# COUNTYFP      9
# COUNTYNS      9
# AFFGEOID      9
# GEOID         9
# NAME          1
# NAMELSAD      1
# STUSPS        9
# STATE_NAME    9
# LSAD          1
# ALAND         9
# AWATER        9
# geometry      9
# dtype: int64
# state_fips      9
# state           9
# state_abbr      9
# zipcode       113
# county          1
# city           82
# dtype: int64

# %%
df_counties['STATE_NAME'].unique()
# Out:
# array(['Arkansas', 'Colorado', 'Michigan', 'Mississippi', 'North Dakota',
#        'Ohio', 'Kentucky', 'Alaska', 'Texas', 'Oklahoma', 'Missouri',
#        'Nebraska', 'Wisconsin', 'Indiana', 'Minnesota', 'Iowa',
#        'Illinois', 'South Dakota', 'Florida', 'Kansas', 'North Carolina',
#        'South Carolina', 'Utah', 'Alabama', 'New Jersey', 'Pennsylvania',
#        'Tennessee', 'Montana', 'Louisiana', 'Puerto Rico', 'Virginia',
#        'California', 'Idaho', 'New York', 'Arizona', 'Georgia',
#        'West Virginia', 'Rhode Island', 'New Mexico', 'Oregon', 'Nevada',
#        'New Hampshire', 'Maine', 'Wyoming', 'Washington', 'Vermont',
#        'District of Columbia', 'Maryland', 'Massachusetts', 'Hawaii',
#        'Connecticut', 'Delaware'], dtype=object)

# %%
df_counties.loc[df_counties['NAME'] == 'Miami'].shape
df_counties.shape
df_counties.info()
df_counties.loc[df_counties['STATE_NAME'] == 'Georgia']
df_counties.sample()
#df_counties.loc[df_counties['NAME'] == 'Gwinnett']
#df_counties.loc[(df_counties['NAME'] == 'Fulton') & (df_counties['STATE_NAME'] == 'Georgia')]
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATEFP     3221 non-null   object
#  1   COUNTYFP    3221 non-null   object
#  2   COUNTYNS    3221 non-null   object
#  3   AFFGEOID    3221 non-null   object
#  4   GEOID       3221 non-null   object
#  5   NAME        3221 non-null   object
#  6   NAMELSAD    3221 non-null   object
#  7   STUSPS      3221 non-null   object
#  8   STATE_NAME  3221 non-null   object
#  9   LSAD        3221 non-null   object
#  10  ALAND       3221 non-null   int64
#  11  AWATER      3221 non-null   int64
#  12  geometry    3221 non-null   geometry
# dtypes: geometry(1), int64(2), object(10)
# memory usage: 327.3+ KB
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID    NAME       NAMELSAD  \
# 1961      35      003  00929108  0500000US35003  35003  Catron  Catron County
#
#      STUSPS  STATE_NAME LSAD        ALAND    AWATER  \
# 1961     NM  New Mexico   06  17933561654  14193499
#
#                                                geometry
# 1961  POLYGON ((-109.04730 33.40978, -109.04661 33.7...

# %%
df_all_ga_counties.sample(5)
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME  \
# 1537      13      033  00347944  0500000US13033  13033      Burke
# 1879      13      313  00353513  0500000US13313  13313  Whitfield
# 2894      13      007  00342832  0500000US13007  13007      Baker
# 2508      13      309  00351278  0500000US13309  13309    Wheeler
# 2475      13      151  01671894  0500000US13151  13151      Henry
#
#               NAMELSAD STUSPS STATE_NAME LSAD       ALAND    AWATER  \
# 1537      Burke County     GA    Georgia   06  2142015889  20578826
# 1879  Whitfield County     GA    Georgia   06   752248663   1579031
# 2894      Baker County     GA    Georgia   06   885665381  18598653
# 2508    Wheeler County     GA    Georgia   06   765314383  12377032
# 2475      Henry County     GA    Georgia   06   825449018  20273034
#
#                                                geometry
# 1537  POLYGON ((-82.27235 32.93780, -82.29118 33.062...
# 1879  POLYGON ((-85.14479 34.76764, -85.06165 34.819...
# 2894  POLYGON ((-84.62758 31.33212, -84.63758 31.433...
# 2508  POLYGON ((-82.92786 32.13527, -82.87486 32.180...
# 2475  POLYGON ((-84.35382 33.39729, -84.29468 33.435...

# %%
center = [37.546647, -90.373178]
zoom = 4
df_all_ga_counties.explore()

# Creating geodata using IpyLeaflet + Carto
usa_map = Map(basemap=basemaps.CartoDB.Positron, center=center, zoom=zoom)
         # DARK THEME BASEMAP = Map(basemap=basemaps.CartoDB.DarkMatter, center=center, zoom=zoom)

# Adding dataframe to be mapped
geodata = GeoData(
    geo_dataframe = df_all_ga_counties.loc[df_all_ga_counties['NAME'] == 'Gwinnett'],
    style={'color': 'white', 'fillColor': '#ff00ff', 'opacity':0.03, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.2},
    hover_style={'fillColor': '#ff00ff' , 'fillOpacity': 0.1},
    name = 'df_counties'
)
usa_map.add_layer(geodata)
usa_map
# Out:
# Map(center=[37.546647, -90.373178], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %%
df_all_ga_counties.loc[df_all_ga_counties['NAME'] == 'Fulton']
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID    NAME       NAMELSAD  \
# 2503      13      121  01694833  0500000US13121  13121  Fulton  Fulton County
#
#      STUSPS STATE_NAME LSAD       ALAND    AWATER  \
# 2503     GA    Georgia   06  1364133162  19666288
#
#                                                geometry
# 2503  POLYGON ((-84.81587 33.52025, -84.80893 33.574...

# %%
df_ga_counties_by_region = pd.read_csv('C:/Users/remar/OneDrive/Desktop/Code/SynthWriter/Current Market Rental Data Analysis/GA_counties_by_region.csv')#.fillna('')
df_ga_counties_by_region
# Out:
#    Region One Region Two Region Three Region Four Region Five Region Six  \
# 0      Bartow      Banks        Butts     Carroll      Barrow    Baldwin
# 1     Catoosa     Dawson      Clayton      Coweta      Clarke       Bibb
# 2   Chattooga    Forsyth         Cobb     Douglas      Elbert   Crawford
# 3    Cherokee   Franklyn       DeKalb       Heard      Greene    Houston
# 4        Dade  Haversham      Fayette       Lamar     Jackson      Jones
# 5      Fannin       Hall       Fulton  Meriwether      Jasper     Monroe
# 6       Floyd       Hart     Gwinnett        Pike     Madison      Peach
# 7      Gilmer    Lumpkin        Henry       Troup      Morgan    Pulaski
# 8      Gordon      Rabun     Rockdale       Upson      Newton     Putnam
# 9    Haralson   Stephens     Spalding         NaN      Oconee     Twiggs
# 10      Murry      Towns          NaN         NaN  Oglethorpe  Wilkinson
# 11   Paulding      Union          NaN         NaN      Walton        NaN
# 12    Pickens        NaN          NaN         NaN         NaN        NaN
# 13       Polk        NaN          NaN         NaN         NaN        NaN
# 14     Walker        NaN          NaN         NaN         NaN        NaN
# 15  Whitfield        NaN          NaN         NaN         NaN        NaN
# 16        NaN        NaN          NaN         NaN         NaN        NaN
# 17        NaN        NaN          NaN         NaN         NaN        NaN
#
#    Region Seven   Region Eight Region Nine Region Ten Region Eleven  \
# 0         Burke  Chattahoochee     Appling      Baker      Atkinson
# 1      Columbia           Clay    Bleckley    Calhoun         Bacon
# 2      Glascosk          Dooly     Candler    Decatur      Ben Hill
# 3       Hancock         Harris       Dodge  Dougherty       Berrien
# 4     Jefferson          Macon     Emanuel      Early      Brantley
# 5       Jenkins         Marion  Jeff Davis      Grady        Brooks
# 6       Lincoln       Muscogee     Johnson        Lee      Charlton
# 7      McDuffie        Quitman     Laurens     Miller        Clinch
# 8      Richmond       Randolph  Montgomery   Mitchell        Coffee
# 9       Screven         Schley    Tattnall   Seminole          Cook
# 10   Taliaferro        Stewart     Telfair    Terrell        Echols
# 11       Warren         Sumter      Toombs     Thomas         Irwin
# 12   Washington         Talbot    Treutlen      Worth        Lanier
# 13       Wilkes         Taylor     Wheeler        NaN       Lowndes
# 14          NaN        Webster      Wilcox        NaN        Pierce
# 15          NaN            NaN         NaN        NaN          Tift
# 16          NaN            NaN         NaN        NaN        Turner
# 17          NaN            NaN         NaN        NaN          Ware
#
#    Region Twelve
# 0          Bryan
# 1        Bulloch
# 2         Camden
# 3        Chatham
# 4      Effingham
# 5          Evans
# 6          Glynn
# 7        Liberty
# 8           Long
# 9       McIntosh
# 10         Wayne
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN

# %%
atl_counties = df_ga_counties_by_region['Region Three'].dropna().tolist()
peripheral_counties = ['Bartow','Paulding','Carroll','Coweta','Newton','Walton','Barrow','Forsyth', 'Hall', 'Douglas', 'Cherokee']
list_test = atl_counties + peripheral_counties

#atl_counties.append(peripheral_counties)
#atl_counties.sort()
atl_counties
peripheral_counties
list_test.sort()
list_test
# Out:
# ['Barrow',
#  'Bartow',
#  'Butts',
#  'Carroll',
#  'Cherokee',
#  'Clayton',
#  'Cobb',
#  'Coweta',
#  'DeKalb',
#  'Douglas',
#  'Fayette',
#  'Forsyth',
#  'Fulton',
#  'Gwinnett',
#  'Hall',
#  'Henry',
#  'Newton',
#  'Paulding',
#  'Rockdale',
#  'Spalding',
#  'Walton']

# %%
# Sourcing zip code county data from public Github repo
geo_data_url = 'https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv'
df_geo = pd.read_csv(geo_data_url)

# %%
# Filtering to counties in the Atlanta Metro region (region 3 on image)
df_atl_counties = df_geo.loc[(df_geo['state_abbr'] == 'GA') &
                             (df_geo['county'].isin(list_test))]         # ORIG CODE = (df_geo['county'].isin(atl_counties))]

#### ORINGIAL CODE WITH STATE_CODE
#df_atl_counties = df_geo.loc[(df_geo['state_abbr'] == ''+state_code+'') &
#                             (df_geo['county'].isin(atl_counties))]

# %%
df_geo
df_geo.loc[(df_geo['state_abbr'] == 'GA') & (df_geo['county'].isin(list_test))]         # ORIG CODE = (df_geo['county'].isin(atl_counties))]
#df_atl_counties
# Out:
#       state_fips    state state_abbr zipcode  county              city
# 5504          13  Georgia         GA   30002  DeKalb  Avondale estates
# 5505          13  Georgia         GA   30004  Fulton        Zcta 30004
# 5506          13  Georgia         GA   30005  Fulton        Zcta 30005
# 5507          13  Georgia         GA   30008    Cobb        Zcta 30008
# 5508          13  Georgia         GA   30011  Barrow        Zcta 30011
# ...          ...      ...        ...     ...     ...               ...
# 5834          13  Georgia         GA   30641  Walton         Good hope
# 5840          13  Georgia         GA   30655  Walton            Monroe
# 5841          13  Georgia         GA   30656  Walton        Zcta 30656
# 5847          13  Georgia         GA   30666  Barrow           Statham
# 5855          13  Georgia         GA   30680  Barrow            Winder
#
# [187 rows x 6 columns]

# %%
df_all_ga_counties.rename(columns={'NAME':'county'}, inplace=True)

display(
    df_all_ga_counties.loc[df_all_ga_counties['county'] != 'Cobb'].sample(5),
    df_atl_counties.loc[df_atl_counties['county'] == 'Cobb'].sample(5),
    df_all_ga_counties.shape,
    df_atl_counties.shape
)
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID      county  \
# 3033      13      305  00350608  0500000US13305  13305       Wayne
# 2254      13      221  00351262  0500000US13221  13221  Oglethorpe
# 1035      13      247  00357592  0500000US13247  13247    Rockdale
# 818       13      147  01687995  0500000US13147  13147        Hart
# 482       13      161  01687999  0500000US13161  13161  Jeff Davis
#
#                NAMELSAD STUSPS STATE_NAME LSAD       ALAND    AWATER  \
# 3033       Wayne County     GA    Georgia   06  1662287070  17768149
# 2254  Oglethorpe County     GA    Georgia   06  1137165335   7708032
# 1035    Rockdale County     GA    Georgia   06   336226920   5900974
# 818         Hart County     GA    Georgia   06   601970613  63521436
# 482   Jeff Davis County     GA    Georgia   06   857075892  11600966
#
#                                                geometry
# 3033  POLYGON ((-82.13301 31.77340, -82.08590 31.823...
# 2254  POLYGON ((-83.30662 33.81144, -83.27593 33.847...
# 1035  POLYGON ((-84.18414 33.64616, -84.11579 33.614...
# 818   POLYGON ((-83.09409 34.41607, -83.05057 34.495...
# 482   POLYGON ((-82.83637 31.81615, -82.65826 31.923...
#       state_fips    state state_abbr zipcode county        city
# 5582          13  Georgia         GA   30127   Cobb  Zcta 30127
# 5537          13  Georgia         GA   30060   Cobb    Marietta
# 5507          13  Georgia         GA   30008   Cobb  Zcta 30008
# 5541          13  Georgia         GA   30067   Cobb    Marietta
# 5551          13  Georgia         GA   30082   Cobb      Smyrna
# (159, 13)
# (187, 6)

# %%
df_atl_counties.sample(5)
# Out:
#       state_fips    state state_abbr zipcode  county         city
# 5753          13  Georgia         GA   30504    Hall  Gainesville
# 5684          13  Georgia         GA   30318  Fulton      Atlanta
# 5701          13  Georgia         GA   30345  DeKalb      Atlanta
# 5641          13  Georgia         GA   30252   Henry   Zcta 30252
# 5665          13  Georgia         GA   30294  DeKalb   Zcta 30294

# %%
# Checking if zip code is valid
df_atl_counties['valid_zip_code'] = df_atl_counties.apply(lambda x: x['zipcode'].isnumeric(), axis=1)
print(df_atl_counties.groupby(['valid_zip_code', 'county'])['zipcode'].count().sort_index())
print(
    '\n{:0,} invalid zip codes found out of {:0,} zip codes total ({:.2f}%): {}'.format(
        df_atl_counties.loc[df_atl_counties['valid_zip_code'] == False]['zipcode'].nunique(),
        df_atl_counties['zipcode'].nunique(),
        (df_atl_counties.loc[df_atl_counties['valid_zip_code'] == False]['zipcode'].nunique() / df_atl_counties['zipcode'].nunique())*100,
        df_atl_counties.loc[df_atl_counties['valid_zip_code'] == False]['zipcode'].unique()
    )
)
# Out:
# valid_zip_code  county
# False           Bartow       1
#                 Butts        1
#                 Cobb         2
# True            Barrow       4
#                 Bartow       8
#                 Butts        3
#                 Carroll      8
#                 Cherokee     7
#                 Clayton      9
#                 Cobb        17
#                 Coweta       7
#                 DeKalb      28
#                 Douglas      4
#                 Fayette      5
#                 Forsyth      2
#                 Fulton      33
#                 Gwinnett    15
#                 Hall        10
#                 Henry        5
#                 Newton       5
#                 Paulding     3
#                 Rockdale     3
#                 Spalding     2
#                 Walton       5
# Name: zipcode, dtype: int64
#
# 4 invalid zip codes found out of 187 zip codes total (2.14%): ['300HH' '301HH' '302HH' '303HH']

# %%
# Creating new df with only our valid zip codes
df_atl_counties_valid_zips = df_atl_counties.loc[df_atl_counties['valid_zip_code'] == True]

# %%
# Merging dataframes
test_merge = \
pd.merge(
    df_all_ga_counties,
    df_atl_counties_valid_zips[['zipcode', 'city', 'county']],
    how='inner', # join type
    on=['county'] # join on this col
)

test_merge.shape
test_merge.sample(3)
# Out:
#     STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID   county  \
# 175      13      089  01687424  0500000US13089  13089   DeKalb
# 15       13      063  01672399  0500000US13063  13063  Clayton
# 30       13      217  01673547  0500000US13217  13217   Newton
#
#            NAMELSAD STUSPS STATE_NAME LSAD      ALAND    AWATER  \
# 175   DeKalb County     GA    Georgia   06  693443933   8858826
# 15   Clayton County     GA    Georgia   06  366879097   6962586
# 30    Newton County     GA    Georgia   06  709148422  13974069
#
#                                               geometry zipcode        city
# 175  POLYGON ((-84.34809 33.84529, -84.34830 33.857...   30340   Doraville
# 15   POLYGON ((-84.45856 33.59444, -84.45805 33.629...   30274   Riverdale
# 30   POLYGON ((-84.04449 33.52578, -84.00328 33.554...   30014  Zcta 30014

# %%
display(
    len(test_merge.loc[test_merge['zipcode'].str.contains('HH')]),
    len(test_merge),
    test_merge['county'].unique(),
    test_merge.sample(5)
)
# Out:
# 0
# 183
# array(['Hall', 'Clayton', 'Coweta', 'Barrow', 'Newton', 'Fayette',
#        'Rockdale', 'Douglas', 'Cobb', 'Cherokee', 'Spalding', 'Bartow',
#        'Butts', 'Walton', 'Gwinnett', 'Carroll', 'Henry', 'Fulton',
#        'Forsyth', 'DeKalb', 'Paulding'], dtype=object)
#     STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID    county  \
# 21       13      077  00326666  0500000US13077  13077    Coweta
# 97       13      135  01688166  0500000US13135  13135  Gwinnett
# 55       13      067  01686112  0500000US13067  13067      Cobb
# 164      13      089  01687424  0500000US13089  13089    DeKalb
# 26       13      013  00356976  0500000US13013  13013    Barrow
#
#             NAMELSAD STUSPS STATE_NAME LSAD       ALAND    AWATER  \
# 21     Coweta County     GA    Georgia   06  1142364907  12680737
# 97   Gwinnett County     GA    Georgia   06  1115653877  15611813
# 55       Cobb County     GA    Georgia   06   880026860  12347127
# 164    DeKalb County     GA    Georgia   06   693443933   8858826
# 26     Barrow County     GA    Georgia   06   417082919   4909580
#
#                                               geometry zipcode        city
# 21   POLYGON ((-85.01536 33.42551, -84.93538 33.437...   30263     Raymond
# 97   POLYGON ((-84.26228 33.98741, -84.18202 33.997...   30071    Norcross
# 55   POLYGON ((-84.73784 34.07940, -84.65924 34.078...   30082      Smyrna
# 164  POLYGON ((-84.34809 33.84529, -84.34830 33.857...   30084      Tucker
# 26   POLYGON ((-83.81768 34.12749, -83.76753 34.066...   30011  Zcta 30011

# %%
#center = [37.546647, -90.373178]
#zoom = 4

test_merge.explore(
    column='NAMELSAD',
    #column='city',
    tooltip=['county', 'GEOID', 'COUNTYFP'],
    popup=True,
    #popup=['county','COUNTYFP','city','zipcode'],
    tiles='CartoDB positron',
    highlight=True,
    cmap='RdYlGn',
    style_kwds=dict(
        #color='white',
        #fillColor='#ff00ff',
        opacity=0.02,
        weight=1.9,
        #dashArray=12,
        fillOpacity=0.04,
        vmin=None,
        vmax=None,
        control_scale=False
     ),
    legend=False,
    legend_kwds=dict(
        caption='County',
        scale=True,
        colorbar=True
    )
)
#style={'color': 'white', 'fillColor': '#ff00ff', 'opacity':0.03, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.2},
#hover_style={'fillColor': '#ff00ff' , 'fillOpacity': 0.1},
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46e5c5ad155cefe85897feed7267bd3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46e5c5ad155cefe85897feed7267bd3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_46e5c5ad155cefe85897feed7267bd3a = L.map(
#                 &quot;map_46e5c5ad155cefe85897feed7267bd3a&quot;,
#                 {
#                     center: [33.846358, -84.42202214995295],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_46e5c5ad155cefe85897feed7267bd3a);
#
#
#
#
#
#             var tile_layer_eaa488b70c52d955e97ccc62133d8cae = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46e5c5ad155cefe85897feed7267bd3a);
#
#
#             map_46e5c5ad155cefe85897feed7267bd3a.fitBounds(
#                 [[33.17862, -85.3381162999059], [34.514096, -83.505928]],
#                 {}
#             );
#
#
#         function geo_json_7d384122ffe9f361c2991d5b7b3ed75b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#a6d96a&quot;, &quot;control_scale&quot;: false, &quot;fillColor&quot;: &quot;#a6d96a&quot;, &quot;fillOpacity&quot;: 0.04, &quot;opacity&quot;: 0.02, &quot;vmax&quot;: null, &quot;vmin&quot;: null, &quot;weight&quot;: 1.9};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;#f88d52&quot;, &quot;control_scale&quot;: false, &quot;fillColor&quot;: &quot;#f88d52&quot;, &quot;fillOpacity&quot;: 0.04, &quot;opacity&quot;: 0.02, &quot;vmax&quot;: null, &quot;vmin&quot;: null, &quot;weight&quot;: 1.9};
#                 case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;#fec776&quot;, &quot;control_scale&quot;: false, &quot;fillColor&quot;: &quot;#fec776&quot;, &quot;fillOpacity&quot;: 0.04, &quot;opacity&quot;: 0.02, &quot;vmax&quot;: null, &quot;vmin&quot;: null, &quot;weight&quot;: 1.9};
#                 case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#a50026&quot;, &quot;control_scale&quot;: false, &quot;fillColor&quot;: &quot;#a50026&quot;, &quot;fillOpacity&quot;: 0.04, &quot;opacity&quot;: 0.02, &quot;vmax&quot;: null, &quot;vmin&quot;: null, &quot;weight&quot;: 1.9};
#                 case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;#66bd63&quot;, &quot;control_scale&quot;: false, &quot;fillColor&quot;: &quot;#66bd63&quot;, &quot;fillOpacity&quot;: 0.04, &quot;opacity&quot;: 0.02, &quot;vmax&quot;: null, &quot;vmin&quot;: null, &quot;weight&quot;: 1.9};
#                 case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;#ffffbf&quot;, &quot;control_scale&quot;: false, &quot;fillColor&quot;: &quot;#ffffbf&quot;, &quot;fillOpacity&quot;: 0.04, &quot;opacity&quot;: 0.02, &quot;vmax&quot;: null, &quot;vmin&quot;: null, &quot;weight&quot;: 1.9};
#                 case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &qu

# %%
df_all_ga_counties.explore(
    column='NAMELSAD',
    tooltip='county',
    popup=['COUNTYFP','GEOID','LSAD'],
    tiles='CartoDB positron',
    highlight=True,
    cmap='cool',
    style_kwds=dict(
        #color='white',
        #fillColor='#ff00ff',
        opacity=0.05,
        weight= 1.9,
        #dashArray= 12,
        fillOpacity= 0.2
     ),
    legend=False
)
#style={'color': 'white', 'fillColor': '#ff00ff', 'opacity':0.03, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.2},
#hover_style={'fillColor': '#ff00ff' , 'fillOpacity': 0.1},
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_459e39643e0c39d580ea117a350f6347 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_459e39643e0c39d580ea117a350f6347&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_459e39643e0c39d580ea117a350f6347 = L.map(
#                 &quot;map_459e39643e0c39d580ea117a350f6347&quot;,
#                 {
#                     center: [32.6807125, -83.2241475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_459e39643e0c39d580ea117a350f6347);
#
#
#
#
#
#             var tile_layer_e2a44af1dad56d67f7d5c5af757e27ee = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_459e39643e0c39d580ea117a350f6347);
#
#
#             map_459e39643e0c39d580ea117a350f6347.fitBounds(
#                 [[30.360766, -85.605165], [35.000659, -80.84313]],
#                 {}
#             );
#
#
#         function geo_json_61252b6106032b24008b2abb0f4e7919_styler(feature) {
#             switch(feature.id) {
#                 case &quot;94&quot;:
#                     return {&quot;color&quot;: &quot;#8e71ff&quot;, &quot;fillColor&quot;: &quot;#8e71ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;131&quot;:
#                     return {&quot;color&quot;: &quot;#12edff&quot;, &quot;fillColor&quot;: &quot;#12edff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;142&quot;:
#                     return {&quot;color&quot;: &quot;#837cff&quot;, &quot;fillColor&quot;: &quot;#837cff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;164&quot;:
#                     return {&quot;color&quot;: &quot;#8c73ff&quot;, &quot;fillColor&quot;: &quot;#8c73ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;222&quot;:
#                     return {&quot;color&quot;: &quot;#38c7ff&quot;, &quot;fillColor&quot;: &quot;#38c7ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;238&quot;:
#                     return {&quot;color&quot;: &quot;#619eff&quot;, &quot;fillColor&quot;: &quot;#619eff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;244&quot;:
#                     return {&quot;color&quot;: &quot;#d827ff&quot;, &quot;fillColor&quot;: &quot;#d827ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;447&quot;:
#                     return {&quot;color&quot;: &quot;#7c83ff&quot;, &quot;fillColor&quot;: &quot;#7c83ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;481&quot;:
#                     return {&quot;color&quot;: &quot;#6e91ff&quot;, &quot;fillColor&quot;: &quot;#6e91ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;482&quot;:
#                     return {&quot;color&quot;: &quot;#8080ff&quot;, &quot;fillColor&quot;: &quot;#8080ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;484&quot;:
#                     return {&quot;color&quot;: &quot;#9d62ff&quot;, &quot;fillColor&quot;: &quot;#9d62ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 1.9};
#                 case &quot;487&quot;:
#                     return {&quot;color&quot;: &quot;#ad52ff&quot;, &quot;fillColor&quot;: &quot;#ad52ff&quot;, &quot;fillOpacity&q
